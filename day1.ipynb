# %%
print("helllo","world",sep="-",end=" ")
print("This is a new line")
#To print the as it is format in text we use triple quotes (3*"")
print("""THis is a 
python line printed
by triple quotes
      1
 2
      3""")
# Out:
# helllo-world This is a new line
# THis is a #To print the as it is format in text
# python line printed
# by triple quotes
#       1
#  2
#       3

# %%
a=10
print(a,type(a))
a="STING"
print(a,type(a))
# Out:
# 10 <class 'int'>
# STING <class 'str'>

# %%
a=10
b=10.0
print(id(a),id(b))#Gives memory location
# Out:
# 140706641872072 2372789507280

# %%
x=int(input("Enter your shoe size:"))
print(x)
# Out:
# 26

# %%
integer=45
#String format
print(f"This is an integer value:{integer}")
a=200
print(f"Number formateed is : {a:.2f}")
# Out:
# This is an integer value:45
# Number formateed is : 200.00

# %%
a="HELLO"
b="Hai"
print(a+b)
c=a+b
print(c.lower())
sentence="this is a title"
print(sentence.title())
d=c.center(30,"-")
print(d)
print(sentence.count("i"))
d="\tRam\tnam\tSatya\thai"
print(d.expandtabs(10)) #Replace tabs with given sized spaces default-8spaces
# Out:
# HELLOHai
# hellohai
# This Is A Title
# -----------HELLOHai-----------
# 3
#           Ram       nam       Satya     hai

# %%
a="This is another line"
print(a.find("is"))#Returns -1
print(a.index("is"))#Throws value error
print(a.isalpha(),a.isnumeric(),a.isdecimal())
s="-"
seq=("a","b","c")
s=s.join(seq)
print(s)
# Out:
# 2
# 2
# False False False
# a-b-c

# %%
st="abcd"
print(st.ljust(10,"-"))
print(st.rjust(30,'?'))
inp="         Hello this is spaced input     "
print(inp.lstrip())
print(inp.rstrip())
print(inp.strip())
st=st.replace("a","A")
print(st)
inp="Hello\nThis\nis\nmy\ncomputer"
print(inp.splitlines())
# Out:
# abcd------
# ??????????????????????????abcd
# Hello this is spaced input
#          Hello this is spaced input
# Hello this is spaced input
# Abcd
# ['Hello', 'This', 'is', 'my', 'computer']

# %%
l="tipon"
e="12345"
st="this is python!"
encoding=st.maketrans(l,e)
print(st.translate(encoding))
# Out:
# 1h2s 2s 3y1h45!

# %%
a="This is python"
b="is"
print((a is b))
print(b in a)
# Out:
# False
# True

# %%
#Conditional statments
if 8>6:
    print("Greater")
elif 4<2:
    print("Small")
elif 6<4:
    print("Smaller")
else:
    print("NoTA")

#Ternary
print("Bigger") if(1>9) else print("Smaller")
# Out:
# Greater
# Smaller

# %%
for i in range(5,20,2):
    print(i)
else:
    print("Not in loop")
for i in range(0,11,1):
    if(i%2==0):
        continue
    print(i)
# Out:
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19
# Not in loop
# 1
# 3
# 5
# 7
# 9

# %%
num=int(input("Enter number:"))
for i in range(1,11,1):
    print(f"{num} * {i} = {num*i}")
# Out:
# 5 * 1=5
# 5 * 2=10
# 5 * 3=15
# 5 * 4=20
# 5 * 5=25
# 5 * 6=30
# 5 * 7=35
# 5 * 8=40
# 5 * 9=45
# 5 * 10=50
